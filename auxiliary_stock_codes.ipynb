# %%
import os
import io
import requests
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as  plt

# %%
aapl = yf.Ticker('aapl')
aapl_data = aapl.history(start="2020-01-01",interval='1d')##(period="max")
aapl_data.plot.line( y='Close')
plt.show()

# %%
aapl_data.head()
# Out:
#                  Open       High        Low      Close     Volume  Dividends  \
# Date
# 2019-12-31  71.754677  72.682763  71.653205  72.675339  100805600        0.0
# 2020-01-02  73.316325  74.395384  73.056464  74.333511  135480400        0.0
# 2020-01-03  73.541543  74.390431  73.380676  73.610840  146322800        0.0
# 2020-01-06  72.709988  74.236995  72.452596  74.197395  118387200        0.0
# 2020-01-07  74.207298  74.469636  73.623226  73.848442  108872000        0.0
#
#             Stock Splits
# Date
# 2019-12-31           0.0
# 2020-01-02           0.0
# 2020-01-03           0.0
# 2020-01-06           0.0
# 2020-01-07           0.0

# %%
msft = yf.Ticker('msft')
msft_data = msft.history(start="2020-09-01",interval='1d')
msft_data.reset_index(inplace=True)
msft_data['symbol']= 'msft'
msft_data.head()
# Out:
#         Date        Open        High         Low       Close    Volume  \
# 0 2020-08-31  226.407249  228.102806  223.724270  224.941086  28774200
# 1 2020-09-01  224.921145  226.856082  223.843964  226.676559  25791200
# 2 2020-09-02  227.374722  232.251952  226.756345  231.045105  34080800
# 3 2020-09-03  228.671335  228.711224  214.398704  216.732590  58400300
# 4 2020-09-04  214.538338  217.789820  204.654212  213.690552  59664100
#
#    Dividends  Stock Splits symbol
# 0        0.0             0   msft
# 1        0.0             0   msft
# 2        0.0             0   msft
# 3        0.0             0   msft
# 4        0.0             0   msft

# %%
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 163000,
# ...

# %%
##### Per
print('Tailing Per:',msft.info['trailingPE'])

##### Per when last benefits ???
print('Foward Per.:',msft.info['forwardPE'])

##### Cap Market
print('Market Cap.:',msft.info['marketCap'])

### Benefits
print('Last Benefits (MarketCap/Per Forward):?',msft.info['marketCap']/msft.info['forwardPE'])

## Book Value
print('Book Value:?',msft.info['bookValue'])
print('Price to Book Value:?',msft.info['priceToBook'])
# Out:
# Tailing Per: 36.446995
# Foward Per.: 30.216316
# Market Cap.: 1843695583232
# Last Benefits (MarketCap/Per Forward):? 61016557519.1893
# Book Value:? 17.259
# Price to Book Value:? 14.163624

# %%
# show actions (dividends, splits)
msft.actions

# show dividends
msft.dividends

# show splits
msft.splits
# Out:
# Series([], Name: Stock Splits, dtype: int64)

# %%
aapl = yf.Ticker('aapl')
aapl.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 147000,
# ...

# %%
xone = yf.Ticker('xone')

# %%
xone.info
# Out:
# {'zip': '15642',
#  'sector': 'Industrials',
#  'fullTimeEmployees': 271,
# ...
